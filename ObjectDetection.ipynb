# %%
"# 1. Install and Import Dependencies"
# !pip install tensorflow tensorflow-gpu pixellib opencv-python
# Out:
# Requirement already satisfied: tensorflow in c:\python\python310\lib\site-packages (2.8.0)
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.8.0-cp310-cp310-win_amd64.whl (438.0 MB)
#      ---------------------------------------- 438.0/438.0 MB ? eta 0:00:00
# Collecting pixellib
#   Downloading pixellib-0.7.1-py3-none-any.whl (430 kB)
#      -------------------------------------- 430.3/430.3 KB 3.0 MB/s eta 0:00:00
# Collecting opencv-python
#   Downloading opencv_python-4.5.5.62-cp36-abi3-win_amd64.whl (35.4 MB)
#      ---------------------------------------- 35.4/35.4 MB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\python\python310\lib\site-packages (from tensorflow) (1.44.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\python\python310\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: setuptools in c:\python\python310\lib\site-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\python\python310\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: flatbuffers>=1.12 in c:\python\python310\lib\site-packages (from tensorflow) (2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\python\python310\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\python\python310\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: libclang>=9.0.1 in c:\python\python310\lib\site-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: gast>=0.2.1 in c:\python\python310\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\python\python310\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: numpy>=1.20 in c:\python\python310\lib\site-packages (from tensorflow) (1.22.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\python\python310\lib\site-packages (from tensorflow) (0.24.0)
# Requirement already satisfied: six>=1.12.0 in c:\python\python310\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\python\python310\lib\site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: wrapt>=1.11.0 in c:\python\python310\lib\site-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\python\python310\lib\site-packages (from tensorflow) (2.8.0.dev2021122109)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\python\python310\lib\site-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\python\python310\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\python\python310\lib\site-packages (from tensorflow) (2.8.0)
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20220212.tar.gz (49 kB)
#      -------------------------------------- 49.9/49.9 KB 364.0 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting iopath
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting cloudpickle
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      -------------------------------------- 829.2/829.2 KB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Collecting hydra-core
#   Downloading hydra_core-1.1.1-py3-none-any.whl (145 kB)
#      -------------------------------------- 145.8/145.8 KB 1.2 MB/s eta 0:00:00
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp310-cp310-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 3.8 MB/s eta 0:00:00
# Collecting imantics
#   Downloading imantics-0.1.12.tar.gz (13 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pillow
#   Downloading Pillow-9.0.1-cp310-cp310-win_amd64.whl (3.2 MB)
#      ---------------------------------------- 3.2/3.2 MB 2.2 MB/s eta 0:00:00
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting omegaconf
#   Downloading omegaconf-2.1.1-py3-none-any.whl (74 kB)
#      -------------------------------------- 74.7/74.7 KB 591.4 kB/s eta 0:00:00
# Collecting imgaug
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#      -------------------------------------- 948.0/948.0 KB 2.5 MB/s eta 0:00:00
# Collecting labelme2coco
#   Downloading labelme2coco-0.2.1-py3-none-any.whl (18 kB)
# Collecting Cython
#   Downloading Cython-0.29.28-py2.py3-none-any.whl (983 kB)
#      -------------------------------------- 983.8/983.8 KB 3.7 MB/s eta 0:00:00
# Collecting black
#   Downloading black-22.1.0-cp310-cp310-win_amd64.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 4.3 MB/s eta 0:00:00
# Collecting tqdm
#   Downloading tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
#      ---------------------------------------- 76.2/76.2 KB 1.0 MB/s eta 0:00:00
# Collecting pyQt5
#   Downloading PyQt5-5.15.6-cp36-abi3-win_amd64.whl (6.7 MB)
#      ---------------------------------------- 6.7/6.7 MB 4.1 MB/s eta 0:00:00
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting scikit-image

# %%
import pixellib
from pixellib.instance import instance_segmentation
import cv2
# Out:
#   Downloading scikit_image-0.19.2-cp310-cp310-win_amd64.whl (12.6 MB)
#      ---------------------------------------- 12.6/12.6 MB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\python\python310\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\python\python310\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\python\python310\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.6.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\python\python310\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\python\python310\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\python\python310\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\python\python310\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.27.1)
# Collecting click>=8.0.0
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      -------------------------------------- 97.5/97.5 KB 429.8 kB/s eta 0:00:00
# Collecting tomli>=1.1.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: platformdirs>=2 in c:\python\python310\lib\site-packages (from black->pixellib) (2.4.0)
# Collecting pathspec>=0.9.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp310-cp310-win_amd64.whl (151 kB)
#      -------------------------------------- 151.7/151.7 KB 1.0 MB/s eta 0:00:00
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Collecting antlr4-python3-runtime==4.8
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      -------------------------------------- 112.4/112.4 KB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting lxml
#   Downloading lxml-4.8.0-cp310-cp310-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 4.4 MB/s eta 0:00:00
# Collecting xmljson
#   Downloading xmljson-0.2.1-py2.py3-none-any.whl (10 kB)
# Collecting Shapely
#   Downloading Shapely-1.8.1.post1-cp310-cp310-win_amd64.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 3.3 MB/s eta 0:00:00
# Collecting scipy
#   Downloading scipy-1.8.0-cp310-cp310-win_amd64.whl (37.0 MB)
#      ---------------------------------------- 37.0/37.0 MB 3.5 MB/s eta 0:00:00
# Collecting imageio
#   Downloading imageio-2.16.0-py3-none-any.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 2.0 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.2.0-cp310-cp310-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 3.8 MB/s eta 0:00:00
# Collecting networkx>=2.2
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\python\python310\lib\site-packages (from scikit-image->pixellib) (21.3)
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.2.9-py3-none-any.whl (180 kB)
#      -------------------------------------- 180.3/180.3 KB 1.5 MB/s eta 0:00:00
# Collecting sahi>=0.8.19
#   Downloading sahi-0.9.0-py3-none-any.whl (78 kB)
#      -------------------------------------- 79.0/79.0 KB 739.0 kB/s eta 0:00:00
# Requirement already satisfied: jsonschema>=2.6.0 in c:\python\python310\lib\site-packages (from labelme2coco->pixellib) (4.4.0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.29.1-py3-none-any.whl (895 kB)
#      -------------------------------------- 895.5/895.5 KB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python\python310\lib\site-packages (from matplotlib->pixellib) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python\python310\lib\site-packages (from matplotlib->pixellib) (2.8.2)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.2-cp310-cp310-win_amd64.whl (52 kB)
#      -------------------------------------- 52.1/52.1 KB 299.3 kB/s eta 0:00:00
# Collecting PyQt5-Qt5>=5.15.2
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#      ---------------------------------------- 50.1/50.1 MB 2.0 MB/s eta 0:00:00
# Collecting PyQt5-sip<13,>=12.8
#   Downloading PyQt5_sip-12.9.1-cp310-cp310-win_amd64.whl (77 kB)
#      -------------------------------------- 77.7/77.7 KB 613.0 kB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\python\python310\lib\site-packages (from tqdm->pixellib) (0.4.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\python\python310\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\python\python310\lib\site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\python\python310\lib\site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.10.8)
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      -------------------------------------- 87.7/87.7 KB 549.2 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: pywin32>=226 in c:\python\python310\lib\site-packages (from portalocker->iopath->pixellib) (303)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Building wheels for collected packages: future, fvcore, antlr4-python3-runtime, imantics, fire
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=871afc6ad43ebc47d643c070854fb10947d07e84f5d694c119e2e1999cce56ae
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\22\73\06\557dc4f4ef68179b9d763930d6eec26b88ed7c389b19588a1c
#   Building wheel for fvcore (setup.py): started
#   Building wheel for fvcore (setup.py): finished with status 'done'
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20220212-py3-none-any.whl size=61216 sha256=972e40644ff46f85096af7002c71098d738de72aa4685a0500a57224f2f507b1
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\dd\06\ec\bcee6f95019f45bf85832294a3bb1022161f399da6d9d475a3
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141230 sha256=d28fa8e40d79a7b6e01bacaf1e5874d2121ada505eb95e540f38e4636b36c3a5
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\a7\20\bd\e1477d664f22d99989fd28ee1a43d6633dddb5cb9e801350d5
#   Building wheel for imantics (setup.py): started
#   Building wheel for imantics (setup.py): finished with status 'done'
#   Created wheel for imantics: filename=imantics-0.1.12-py3-none-any.whl size=16033 sha256=6c0f878e43b75ac261c07142b31d6234c57af3b88751a7033f07b0e986efcbe2
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\56\6a\be\4c60e88b14abec4e93234a1f7f91ce8abe1ae88a2b3eaad3ac
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=f02f9ce4071cbd817a8093e50f0b1f76dfd62c306de7ffc676bc466595c5df9a
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\26\9a\dd\2818b1b023daf077ec3e625c47ae446aca587a5abe48e05212
# Successfully built future fvcore antlr4-python3-runtime imantics fire
# Installing collected packages: xmljson, tabulate, PyQt5-Qt5, mypy-extensions, dataclasses, antlr4-python3-runtime, tqdm, tomli, tifffile, terminaltables, Shapely, scipy, pyyaml, PyWavelets, PyQt5-sip, pydot, portalocker, pillow, pathspec, opencv-python, networkx, lxml, kiwisolver, future, fonttools, fire, Cython, cycler, cloudpickle, click, yacs, sahi, pyQt5, omegaconf, matplotlib, iopath, imantics, imageio, black, scikit-image, labelme2coco, hydra-core, fvcore, imgaug, tensorflow-gpu, pixellib
# Successfully installed Cython-0.29.28 PyQt5-Qt5-5.15.2 PyQt5-sip-12.9.1 PyWavelets-1.2.0 Shapely-1.8.1.post1 antlr4-python3-runtime-4.8 black-22.1.0 click-8.0.4 cloudpickle-2.0.0 cycler-0.11.0 dataclasses-0.6 fire-0.4.0 fonttools-4.29.1 future-0.18.2 fvcore-0.1.5.post20220212 hydra-core-1.1.1 imageio-2.16.0 imantics-0.1.12 imgaug-0.4.0 iopath-0.1.9 kiwisolver-1.3.2 labelme2coco-0.2.1 lxml-4.8.0 matplotlib-3.5.1 mypy-extensions-0.4.3 networkx-2.6.3 omegaconf-2.1.1 opencv-python-4.5.5.62 pathspec-0.9.0 pillow-9.0.1 pixellib-0.7.1 portalocker-2.4.0 pyQt5-5.15.6 pydot-1.4.2 pyyaml-6.0 sahi-0.9.0 scikit-image-0.19.2 scipy-1.8.0 tabulate-0.8.9 tensorflow-gpu-2.8.0 terminaltables-3.1.10 tifffile-2022.2.9 tomli-2.0.1 tqdm-4.62.3 xmljson-0.2.1 yacs-0.1.8
# Matplotlib is building the font cache; this may take a moment.

# %%
"# 2. Setup Model"
segmentation_model = instance_segmentation()
segmentation_model.load_model('mask_rcnn_coco.h5')
# Out:
# WARNING:tensorflow:From C:\Python\Python310\lib\site-packages\tensorflow\python\util\deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %%
# 3. Real Time Capture
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
   # Apply instance segmentation\n",
    res = segmentation_model.segmentFrame(frame, show_bboxes=True)
    image = res[1]
    cv2.imshow('Instance Segmentation', image)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# segmentation_model.segmentFrame??
# Out:
# C:\Python\Python310\lib\site-packages\keras\engine\training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
